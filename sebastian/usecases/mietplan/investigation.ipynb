# %% [markdown]
# # Import Necessary Libraries
# Import libraries required for interacting with the Git repository and file system, such as `git` (from GitPython) and `os`.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %% [markdown]
# # Configure Repository and Branches
# Initialize the repository object from the current working directory. Define the source branch (current) and the target branch to compare against (e.g., 'mietplan').

# %%
from cloud.dependencies.services import resolve_mietplan_service

service = resolve_mietplan_service()

# %%
from datetime import timedelta


result = service.process_new_files(max_file_age=timedelta(days=9))
print(result)
