# %%
for folder in client.walk_from_top_folder():
    print(f"Folder: {folder.path}")
    for file in folder.files:
        print(f"  File: {file.name}")

# %%
credentials = get_secret(SecretKeys.MietplanCredentials, MietplanCredentials)
client = MietplanClient(credentials)

# %%
from sebastian.clients.mietplan import MietplanClient
from sebastian.clients.mietplan.credentials import MietplanCredentials
from cloud.helper.secrets import get_secret, SecretKeys

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %% [markdown]
# # Mietplan Client Investigation
