# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %%
from cloud.dependencies.clients import resolve_google_task_client


client = resolve_google_task_client()

# %%
s = client._service

# %%
type(s)
# Out:
# googleapiclient.discovery.Resource

# %%
t = s.tasks()
type(t)
# Out:
# googleapiclient.discovery.Resource

# %%
t.insert
# Out:
# <bound method createMethod.<locals>.method of <googleapiclient.discovery.Resource object at 0x7f5fb73b4fe0>>

# %%
from typing import Protocol

class GoogleApiTasksResource:
    ...

class GoogleApiResource(Protocol):
    def tasks(self) -> "GoogleApiTasksResource":
        ...
