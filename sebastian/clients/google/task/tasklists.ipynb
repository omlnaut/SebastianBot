# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %%
from cloud.dependencies.clients import resolve_google_task_client


client = resolve_google_task_client()

# %%
client._fetch_tasklists()
# Out:
# [TaskList(kind='tasks#taskList', id='MDY0Mzc2NjgyMDc4MTc0Nzg3Mjk6MDow', etag='"Dab9weSUzaw"', title='Meine Aufgaben', updated=datetime.datetime(2026, 3, 22, 20, 35, 7, 568000, tzinfo=TzInfo(0)), selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/MDY0Mzc2NjgyMDc4MTc0Nzg3Mjk6MDow'),
#  TaskList(kind='tasks#taskList', id='WFRzM0JfdkdTXzl4WHVHNw', etag='"UaTJ2u4s880"', title='Mangas', updated=datetime.datetime(2026, 3, 22, 4, 50, 6, 576000, tzinfo=TzInfo(0)), selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/WFRzM0JfdkdTXzl4WHVHNw'),
#  TaskList(kind='tasks#taskList', id='Y2ZmZ3BsSVNld2x1LWk3NA', etag='"j0yCZBs7io4"', title='Azure', updated=datetime.datetime(2025, 1, 4, 13, 38, 51, 962000, tzinfo=TzInfo(0)), selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/Y2ZmZ3BsSVNld2x1LWk3NA'),
#  TaskList(kind='tasks#taskList', id='MzJlRkQwejZRYm0xeWtiMA', etag='"2JQ0wUWOS1Y"', title='Smart Home', updated=datetime.datetime(2025, 1, 4, 13, 32, 59, 476000, tzinfo=TzInfo(0)), selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/MzJlRkQwejZRYm0xeWtiMA'),
#  TaskList(kind='tasks#taskList', id='dTJVTXhYZk1feDlXNlBFMA', etag='"8j_ImCxh7FE"', title='Bibo', updated=datetime.datetime(2026, 3, 22, 20, 37, 20, 789000, tzinfo=TzInfo(0)), selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/dTJVTXhYZk1feDlXNlBFMA')]
