# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cloud.dependencies.clients import resolve_google_task_client


client = resolve_google_task_client()

# %%
client.fetch_tasklists()
# Out:
# [TaskList(kind='tasks#taskList', id='MDY0Mzc2NjgyMDc4MTc0Nzg3Mjk6MDow', etag='"Uncko3cWmf4"', title='Meine Aufgaben', updated='2026-03-03T20:30:46.319Z', selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/MDY0Mzc2NjgyMDc4MTc0Nzg3Mjk6MDow'),
#  TaskList(kind='tasks#taskList', id='WFRzM0JfdkdTXzl4WHVHNw', etag='"05CR-6hINfc"', title='Mangas', updated='2026-03-02T06:41:02.608Z', selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/WFRzM0JfdkdTXzl4WHVHNw'),
#  TaskList(kind='tasks#taskList', id='Y2ZmZ3BsSVNld2x1LWk3NA', etag='"j0yCZBs7io4"', title='Azure', updated='2025-01-04T13:38:51.962Z', selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/Y2ZmZ3BsSVNld2x1LWk3NA'),
#  TaskList(kind='tasks#taskList', id='MzJlRkQwejZRYm0xeWtiMA', etag='"2JQ0wUWOS1Y"', title='Smart Home', updated='2025-01-04T13:32:59.476Z', selfLink='https://www.googleapis.com/tasks/v1/users/@me/lists/MzJlRkQwejZRYm0xeWtiMA')]

# %%
from sebastian.protocols.google_task.models import TaskListIds
from sebastian.shared.dates import get_end_of_day


client.create_task_with_notes(tasklist_id=TaskListIds.Default, title="testi title", notes="testi_notes", due_date=get_end_of_day())
# Out:
# Task(title='testi title', tasklist=<TaskListIds.Default: 'MDY0Mzc2NjgyMDc4MTc0Nzg3Mjk6MDow'>, due=datetime.datetime(2026, 3, 3, 0, 0, tzinfo=TzInfo(0)), notes='testi_notes', webViewLink='https://tasks.google.com/task/07zhzw03BrSuDkqX?sa=6')

# %%
from datetime import datetime

from sebastian.clients.google.task.client.create_task_with_notes import build_task_body


body = build_task_body("title", "notes", get_end_of_day())
created = (
    client._service.tasks().insert(tasklist=TaskListIds.Mangas.value, body=body).execute()
)

# %%
body
# Out:
# {'title': 'title', 'notes': 'notes', 'due': '2026-03-03T23:59:59+01:00'}

# %%
created
# Out:
# {'kind': 'tasks#task',
#  'id': 'UktmU2Y5UV9wdzlueWhRbw',
#  'etag': '"fwpePNgZeF4"',
#  'title': 'title',
#  'updated': '2026-03-03T21:09:40.590Z',
#  'selfLink': 'https://www.googleapis.com/tasks/v1/lists/WFRzM0JfdkdTXzl4WHVHNw/tasks/UktmU2Y5UV9wdzlueWhRbw',
#  'position': '00000000000000000000',
#  'notes': 'notes',
#  'status': 'needsAction',
#  'due': '2026-03-03T00:00:00.000Z',
#  'links': [],
#  'webViewLink': 'https://tasks.google.com/task/RKfSf9Q_pw9nyhQo?sa=6'}
