# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cloud.dependencies.clients import resolve_gmail_client


client = resolve_gmail_client()
s = client._service

# %%
from datetime import datetime

from sebastian.usecases.shared.query_builder import GmailQueryBuilder

builder = GmailQueryBuilder().on_date(datetime(2026,5,15))
query = builder.build()

# %%
s.fetch_message_ids(query=query)
# Out:
# [MessageId(id='19e2c64207775195'),
#  MessageId(id='19e2c618ebb8676a'),
#  MessageId(id='19e2be6ce463cc6f'),
#  MessageId(id='19e2bbac38615b20'),
#  MessageId(id='19e2b8920f4c5348'),
#  MessageId(id='19e2b74ee22529db'),
#  MessageId(id='19e2aa96f5685ac5')]

# %%
mails = client.fetch_mails(query)

# %%
read_state_by_mail = [
    {
        "id": mail.id,
        "is_unread": "UNREAD" in mail.labelIds,
        "labels": mail.labelIds,
    }
    for mail in mails
]
read_state_by_mail[:5]
# Out:
# [{'id': '19e2c64207775195',
#   'is_unread': True,
#   'labels': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX']},
#  {'id': '19e2c618ebb8676a',
#   'is_unread': True,
#   'labels': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX']},
#  {'id': '19e2be6ce463cc6f',
#   'is_unread': True,
#   'labels': ['UNREAD', 'IMPORTANT', 'CATEGORY_UPDATES', 'INBOX']},
#  {'id': '19e2bbac38615b20',
#   'is_unread': False,
#   'labels': ['IMPORTANT', 'CATEGORY_UPDATES', 'INBOX']},
#  {'id': '19e2b8920f4c5348',
#   'is_unread': True,
#   'labels': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX']}]
