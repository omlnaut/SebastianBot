# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %% [markdown]
# # View Gmail Labels
# Run the code cells below to fetch and display all labels available in your Gmail account.

# %%
from cloud.dependencies.clients import resolve_gmail_client

gmail_client = resolve_gmail_client()
labels = gmail_client.get_labels()
len(labels)
# Out:
# 49

# %%
sebastian_labels = [label for label in labels if "sebastian" in label.name.lower()]
sebastian_labels
# Out:
# [GmailLabelResponse(id='Label_1123571739877587128', name='Sebastian/Processed', type='user', message_list_visibility=None, label_list_visibility=None),
#  GmailLabelResponse(id='Label_7530354033606578606', name='Sebastian', type='user', message_list_visibility=None, label_list_visibility=None)]
