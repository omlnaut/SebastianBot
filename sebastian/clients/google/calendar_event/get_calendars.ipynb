# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %%
from cloud.dependencies.clients import load_google_credentials


credentials = load_google_credentials()

# %%
from sebastian.clients.google.calendar_event.client import CalendarEventClient

client = CalendarEventClient(credentials)
calendars = client.get_calendars()

for calendar in calendars:
    print(f"{calendar.title} ({calendar.id})")
# Out:
# Kalenderwochen (e_2_de#weeknum@group.v.calendar.google.com)
# Bardiensteinteilung (j1c57li3h1sstka86711ocfhh4@group.calendar.google.com)
# Feiertage in Deutschland (de.german#holiday@group.v.calendar.google.com)
# Veranstaltungen_Erdgeschoß (kultur.altemensa@googlemail.com)
# Katja und Oli (0l0c1ieklrasrfv48equjs3tdk@group.calendar.google.com)
# Familienkalender (v36uum3ir6rteujklq12rbh1j0@group.calendar.google.com)
# oneironaut.oml@gmail.com (oneironaut.oml@gmail.com)
# Familie (family00785340401979913864@group.calendar.google.com)
# Confirm? (7e1368aa848a1cf2404d4d89bf0d1fce8fb1249bf87be5544ff604e72afa61f6@group.calendar.google.com)

# %%
calendar
# Out:
# Calendar(id='7e1368aa848a1cf2404d4d89bf0d1fce8fb1249bf87be5544ff604e72afa61f6@group.calendar.google.com', title='Confirm?')
