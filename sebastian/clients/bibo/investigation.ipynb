# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %%
from cloud.dependencies.clients import resolve_bibo_client


client = resolve_bibo_client()

# %%
account_html = client._fetch_account_page()
print(f"Content length: {len(account_html)}")
"kunterbunt" in account_html
# Out:
# Content length: 33356
# True
