# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/workspaces/SebastianBot")

# %%
sub_id = "fcdc0c79-2df2-4d19-8f7e-607a4fa79363"
resource_group = "Sebastian_group"
function_app_name = "Sebastian"

# %%
from azure.identity import DefaultAzureCredential
from azure.mgmt.web import WebSiteManagementClient


credential = DefaultAzureCredential()
client = WebSiteManagementClient(credential, sub_id)

# %%
app_settings = client.web_apps.list_application_settings(
    resource_group_name=resource_group, name=function_app_name
)

# %%
app_settings.properties
